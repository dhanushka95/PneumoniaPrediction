# %%
import numpy
from flask import Flask
from flask import request
from keras.layers import Dense,Dropout,Flatten,MaxPooling2D,Convolution2D,Activation
from keras.models import Sequential
from tensorflow.python.keras.backend import set_session
from keras.models import load_model
from keras.wrappers.scikit_learn import KerasClassifier
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow 
from io import BytesIO

app = Flask(__name__)

global graph
graph = tensorflow.get_default_graph()
sess = tensorflow.Session()

def larger_model():
        model = Sequential()
        model.add(Dense(64,input_dim=2,activation='relu'))
        model.add(Dense(256,activation='relu'))
        model.add(Dropout(0.2))
        model.add(Dense(128,activation='relu'))
        model.add(Dense(1,activation='sigmoid'))

        model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
        return model

#load model
classifire = larger_model()  
set_session(sess)
classifire.load_weights('evaluate_88.h5') 

@app.route("/predict",methods =['POST'])
def predictions(): 
    with graph.as_default():
                 set_session(sess)
                 data = request.args.get('input', '') 
                 print(data)
                 prediction = classifire.predict([[data]])[0]          
    return str(prediction[0])

if __name__ == '__main__':
    app.run(debug=False, port=5003)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5003/ (Press CTRL+C to quit)
# INFO:werkzeug: * Running on http://127.0.0.1:5003/ (Press CTRL+C to quit)
# [2020-11-23 18:07:46,785] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-11-0326dafe1a7e>", line 42, in predictions
#     prediction = classifire.predict([[data]])[0]
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\keras\engine\training.py", line 1441, in predict
#     x, _, _ = self._standardize_user_data(x)
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\keras\engine\training.py", line 579, in _standardize_user_data
#     exception_prefix='input')
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\keras\engine\training_utils.py", line 145, in standardize_input_data
#     str(data_shape))
# ValueError: Error when checking input: expected dense_41_input to have shape (2,) but got array with shape (1,)
# ERROR:__main__:Exception on /predict [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-11-0326dafe1a7e>", line 42, in predictions
#     prediction = classifire.predict([[data]])[0]
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\keras\engine\training.py", line 1441, in predict
#     x, _, _ = self._standardize_user_data(x)
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\keras\engine\training.py", line 579, in _standardize_user_data
#     exception_prefix='input')
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\keras\engine\training_utils.py", line 145, in standardize_input_data
#     str(data_shape))
# ValueError: Error when checking input: expected dense_41_input to have shape (2,) but got array with shape (1,)
# 127.0.0.1 - - [23/Nov/2020 18:07:46] "POST /predict HTTP/1.1" 500 -
# INFO:werkzeug:127.0.0.1 - - [23/Nov/2020 18:07:46] "POST /predict HTTP/1.1" 500 -
# [2020-11-23 18:08:04,304] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-11-0326dafe1a7e>", line 42, in predictions
#     prediction = classifire.predict([[data]])[0]
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\keras\engine\training.py", line 1441, in predict
#     x, _, _ = self._standardize_user_data(x)
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\keras\engine\training.py", line 579, in _standardize_user_data
#     exception_prefix='input')
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\keras\engine\training_utils.py", line 145, in standardize_input_data
#     str(data_shape))
# ValueError: Error when checking input: expected dense_41_input to have shape (2,) but got array with shape (1,)
# ERROR:__main__:Exception on /predict [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-11-0326dafe1a7e>", line 42, in predictions
#     prediction = classifire.predict([[data]])[0]
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\keras\engine\training.py", line 1441, in predict
#     x, _, _ = self._standardize_user_data(x)
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\keras\engine\training.py", line 579, in _standardize_user_data
#     exception_prefix='input')
#   File "C:\ProgramData\Anaconda3\envs\deepkeras\lib\site-packages\keras\engine\training_utils.py", line 145, in standardize_input_data
#     str(data_shape))
# ValueError: Error when checking input: expected dense_41_input to have shape (2,) but got array with shape (1,)
# 127.0.0.1 - - [23/Nov/2020 18:08:04] "POST /predict HTTP/1.1" 500 -
# INFO:werkzeug:127.0.0.1 - - [23/Nov/2020 18:08:04] "POST /predict HTTP/1.1" 500 -
